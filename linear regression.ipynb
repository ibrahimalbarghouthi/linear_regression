# %%
require 'nyaplot'

g = -> (x, t, p) { (t - (x * p)) ** 2 }

gprime = -> (x, t, p) { 2 * x * ( p * x - t) }

f = -> (x) {x * 12}

line = -> (slope, x, b) { slope * x + b }

x = [1, 2, 3, 4, 5, 6, 7, 8]

t = x.map(&f)

iterate = (0..20).step(0.2)

m = iterate.map {|p| x.zip(t).inject(0) {|s, (x, t)| s += g.call(x, t, p) } }

plt = Nyaplot::Plot.new

lin = plt.add(:line, iterate.to_a, m)

p = 20 # starts with

20.times do
  gradient = x.zip(t).inject(0) {|s, (x, t)| s += gprime.call(x, t, p) }
  point =  x.zip(t).inject(0) {|s, (x, t)| s += g.call(x, t, p) }
  
  plt.add(:scatter, [p], [point]).color('rgb(215,48,39)')
  
  ln = line.call(gradient, -1, point)
  ln2 = line.call(gradient, 1, point)

  plt.add(:line, [p - 1, p + 1], [ln, ln2]).color('rgb(214,96,77)')
  
  p -= 0.001 * gradient
end

plt
# Out:
# "if(window['d3'] === undefined ||\n   window['Nyaplot'] === undefined){\n    var path = {\"d3\":\"https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min\",\"downloadable\":\"http://cdn.rawgit.com/domitry/d3-downloadable/master/d3-downloadable\"};\n\n\n\n    var shim = {\"d3\":{\"exports\":\"d3\"},\"downloadable\":{\"exports\":\"downloadable\"}};\n\n    require.config({paths: path, shim:shim});\n\n\nrequire(['d3'], function(d3){window['d3']=d3;console.log('finished loading d3');require(['downloadable'], function(downloadable){window['downloadable']=downloadable;console.log('finished loading downloadable');\n\n\tvar script = d3.select(\"head\")\n\t    .append(\"script\")\n\t    .attr(\"src\", \"http://cdn.rawgit.com/domitry/Nyaplotjs/master/release/nyaplot.js\")\n\t    .attr(\"async\", true);\n\n\tscript[0][0].onload = script[0][0].onreadystatechange = function(){\n\n\n\t    var event = document.createEvent(\"HTMLEvents\");\n\t    event.initEvent(\"load_nyaplot\",false,false);\n\t    window.dispatchEvent(event);\n\t    console.log('Finished loading Nyaplotjs');\n\n\t};\n\n\n});});\n}\n"
# #<Nyaplot::Plot:0x007fcb41b21f60 @properties={:diagrams=>[#<Nyaplot::Diagram:0x007fcb41b131e0 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1"}, :data=>"63e79c06-43ef-49a7-a031-8b5113863648"}, @xrange=[0.0, 20.0], @yrange=[0.0, 29376.0]>, #<Nyaplot::Diagram:0x007fcb41b11ed0 @properties={:type=>:scatter, :options=>{:x=>"data0", :y=>"data1", :color=>"rgb(215,48,39)"}, :data=>"80fef231-7061-4ac5-aec3-065c9815d536"}, @xrange=[20, 20], @yrange=[13056, 13056]>, #<Nyaplot::Diagram:0x007fcb41b10ee0 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1", :color=>"rgb(214,96,77)"}, :data=>"e1da5be3-65bc-4b4a-b5bd-7033b5a185c1"}, @xrange=[19, 21], @yrange=[9792, 16320]>, #<Nyaplot::Diagram:0x007fcb41b0bb98 @properties={:type=>:scatter, :options=>{:x=>"data0", :y=>"data1", :color=>"rgb(215,48,39)"}, :data=>"85d06792-4d04-47f8-8e47-57ea2b83d963"}, @xrange=[16.736, 16.736], @yrange=[4575.657984000001, 4575.657984000001]>, #<Nyaplot::Diagram:0x007fcb41b0ab58 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1", :color=>"rgb(214,96,77)"}, :data=>"8c47cee4-e627-4c8f-8b8b-be17b67c4bb3"}, @xrange=[15.736, 17.736], @yrange=[2643.3699840000013, 6507.945984000002]>, #<Nyaplot::Diagram:0x007fcb41b09898 @properties={:type=>:scatter, :options=>{:x=>"data0", :y=>"data1", :color=>"rgb(215,48,39)"}, :data=>"cc947490-c969-44af-8b96-defbeefdd0aa"}, @xrange=[14.803712, 14.803712], @yrange=[1603.6033997045768, 1603.6033997045768]>, #<Nyaplot::Diagram:0x007fcb41b08858 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1", :color=>"rgb(214,96,77)"}, :data=>"d5707197-1fa9-4965-bbbe-d9248564cb95"}, @xrange=[13.803712, 15.803712], @yrange=[459.68890370457643, 2747.5178957045773]>, #<Nyaplot::Diagram:0x007fcb41b03588 @properties={:type=>:scatter, :options=>{:x=>"data0", :y=>"data1", :color=>"rgb(215,48,39)"}, :data=>"98c52edb-e0cf-45d5-a810-0777d4bbee64"}, @xrange=[13.659797504, 13.659797504], @yrange=[562.0052618740649, 562.0052618740649]>, #<Nyaplot::Diagram:0x007fcb41b02598 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1", :color=>"rgb(214,96,77)"}, :data=>"a21a0c2a-a5dd-400b-9f15-cb652edcf1f5"}, @xrange=[12.659797504, 14.659797504], @yrange=[-115.1921197579353, 1239.2026435060652]>, #<Nyaplot::Diagram:0x007fcb41b01288 @properties={:type=>:scatter, :options=>{:x=>"data0", :y=>"data1", :color=>"rgb(215,48,39)"}, :data=>"e3240b49-e6de-428b-88aa-e2c8dd247513"}, @xrange=[12.982600122368, 12.982600122368], @yrange=[196.9626120974322, 196.9626120974322]>, #<Nyaplot::Diagram:0x007fcb41b00270 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1", :color=>"rgb(214,96,77)"}, :data=>"e800ad30-33a8-40cb-b15a-077f6d94322e"}, @xrange=[11.982600122368, 13.982600122368], @yrange=[-203.93823782871186, 597.8634620235763]>, #<Nyaplot::Diagram:0x007fcb41afaf28 @properties={:type=>:scatter, :options=>{:x=>"data0", :y=>"data1", :color=>"rgb(215,48,39)"}, :data=>"c8f60d5b-3641-4885-9b36-902d6aa51d2c"}, @xrange=[12.581699272441856, 12.581699272441856], @yrange=[69.02830488611457, 69.02830488611457]>, #<Nyaplot::Diagram:0x007fcb41af9f10 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1", :color=>"rgb(214,96,77)"}, :data=>"6b620a7e-ae7a-45e0-97ea-9532d4c35fd7"}, @xrange=[11.581699272441856, 13.581699272441856], @yrange=[-168.30499827016286, 306.361608042392]>, #<Nyaplot::Diagram:0x007fcb41af8c00 @properties={:type=>:scatter, :options=>{:x=>"data0", :y=>"data1", :color=>"rgb(215,48,39)"}, :data=>"9fdee716-27f7-445c-bf3c-a119cc0aaac3"}, @xrange=[12.34436596928558, 12.34436596928558], @yrange=[24.191935843607382, 24.191935843607382]>, #<Nyaplot::Diagram:0x007fcb41af3958 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1", :color=>"rgb(214,96,77)"}, :data=>"63af6070-ce11-436b-8ac5-1c78cb078dfc"}, @xrange=[11.34436596928558, 13.34436596928558], @yrange=[-116.30937962490921, 164.69325131212398]>, #<Nyaplot::Diagram:0x007fcb41af2030 @properties={:type=>:scatter, :options=>{:x=>"data0", :y=>"data1", :color=>" ...
